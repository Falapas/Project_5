# %%
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
motorcycles = pd.read_excel("Motorcycles.xlsx")

# %%
motorcycles
# Out:
#         Brand Country             Model Category  Year  Price    CC  CO2 g/km  \
# 0      Yamaha     JPN            YZF-R1    Sport  2019  19895  1000     167.0
# 1      Yamaha     JPN             XMAX   Scooter  2019   5995   300      74.0
# 2      Yamaha     JPN            MT-125    Naked  2019   5125   125      49.4
# 3    Kawasaki     JPN      Ninja ZX-10R    Sport  2020  20490  1000     136.9
# 4    Kawasaki     JPN              J300  Scooter  2020   5850   300      75.0
# 5    Kawasaki     JPN              Z125    Naked  2020   4990   125      66.0
# 6       Honda     JPN         CBR1000RR    Sport  2019  22200  1000     133.2
# 7       Honda     JPN         Forza 300  Scooter  2019   5825   300      62.6
# 8       Honda     JPN            CB125F    Naked  2019   2750   125      36.2
# 9      Suzuki     JPN       GSX-R1000RA    Sport  2020  19999  1000     137.0
# 10     Suzuki     JPN      Burgman 400A  Scooter  2020   8499   400      97.0
# ...
